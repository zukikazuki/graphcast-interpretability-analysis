# %%
import numpy as np
from pathlib import Path

# Direct path (no config)
ckpt_path = Path("/home/dl-box/Fujikawa/research/machine_learning/graphcast/assets/graphcast-small/weights/graphcast_small_era5_res1p0_pl13_v1.npz")
print("Checkpoint:", ckpt_path)
assert ckpt_path.exists(), f"Checkpoint not found: {ckpt_path}"

npz = np.load(ckpt_path)
num_params = sum(arr.size for arr in npz.values())
num_bytes = sum(arr.nbytes for arr in npz.values())

print(f"num_params: {num_params:,}")
print(f"size (bytes): {num_bytes:,} (~{num_bytes/1024/1024:.2f} MiB)")
# Out:
# Checkpoint: /home/dl-box/Fujikawa/research/machine_learning/graphcast/assets/graphcast-small/weights/graphcast_small_era5_res1p0_pl13_v1.npz
# num_params: 35,979,404
# size (bytes): 143,922,492 (~137.26 MiB)
